# %% [markdown]
# <a href="https://colab.research.google.com/github/thacanh/Detect_circle/blob/main/FineTuningYOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Project/CountingSticks/train.zip -d /content/drive/MyDrive/Project/CountingSticks/train
# !unzip /content/drive/MyDrive/Project/CountingSticks/val.zip -d /content/drive/MyDrive/Project/CountingSticks/val
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3751.txt
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3752.jpg
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3752.txt
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3753.jpg
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3753.txt
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3754.jpg
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3754.txt
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3755.jpg
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3755.txt
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3756.jpg
#   inflating: /content/drive/MyDrive/Project/CountingSticks/train/img3756.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 29.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(data='/content/drive/MyDrive/Project/CountingSticks/data.yaml', epochs=50, batch=16, imgsz=512)
model.info()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 112MB/s]
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.save('/content/drive/MyDrive/Project/CountingSticks/my_model.pt')
